# %%
import pandas as pd

# %%
# Прогнозирование оттока клиентов из банка
# Требуется построить модель, позволяющую предсказывать отток клиентов из банка, т.е. построить классификатор: клиент готов уйти или клиент не готов уйти.
# Подробное описание полей находится по адресу: https://www.kaggle.com/sakshigoyal7/credit-card-customers
df = pd.read_csv('BankChurners.csv')
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# 0                  39  ...       12691.0                  777
# 1                  44  ...        8256.0                  864
# 2                  36  ...        3418.0                    0
# 3                  34  ...        3313.0                 2517
# 4                  21  ...        4716.0                    0
# ...               ...  ...           ...                  ...
# 10122              40  ...        4003.0                 1851
# 10123              25  ...        4277.0                 2186
# 10124              36  ...        5409.0                    0
# 10125              36  ...        5281.0                    0
# 10126              25  ...       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0              11914.0                 1.335             1144              42
# 1               7392.0                 1.541             1291              33
# 2               3418.0                 2.594             1887              20
# 3                796.0                 1.405             1171              20
# 4               4716.0                 2.175              816              28
# ...                ...                   ...              ...             ...
# 10122           2152.0                 0.703            15476             117
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
# [10127 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
# !python -m pip install --upgrade pip
# !pip uninstall numpy scikit-learn imbalanced-learn tensorflow -y
# !pip install numpy==1.26.0
# !pip install scikit-learn==1.3.0
# !pip install imbalanced-learn==0.13.0
# !pip install tensorflow==2.18.0
# Out:
# Requirement already satisfied: pip in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (22.0.4)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 5.3 MB/s eta 0:00:0000:0100:010m
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.4
#     Uninstalling pip-22.0.4:
#       Successfully uninstalled pip-22.0.4
# Successfully installed pip-25.0.1
# Found existing installation: numpy 1.23.5
# Uninstalling numpy-1.23.5:
#   Successfully uninstalled numpy-1.23.5
# Found existing installation: scikit-learn 1.1.3
# Uninstalling scikit-learn-1.1.3:
#   Successfully uninstalled scikit-learn-1.1.3
# Found existing installation: imbalanced-learn 0.9.1
# Uninstalling imbalanced-learn-0.9.1:
#   Successfully uninstalled imbalanced-learn-0.9.1
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# Collecting numpy==1.26.0
#   Downloading numpy-1.26.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (53 kB)
# Downloading numpy-1.26.0-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 7.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-1.26.0
# Collecting scikit-learn==1.3.0
#   Downloading scikit_learn-1.3.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17.3 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from scikit-learn==1.3.0) (1.26.0)
# Requirement already satisfied: scipy>=1.5.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from scikit-learn==1.3.0) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from scikit-learn==1.3.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from scikit-learn==1.3.0) (3.5.0)
# Downloading scikit_learn-1.3.0-cp310-cp310-macosx_12_0_arm64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.3.0
# Collecting imbalanced-learn==0.13.0
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.24.3 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from imbalanced-learn==0.13.0) (1.26.0)
# Requirement already satisfied: scipy<2,>=1.10.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from imbalanced-learn==0.13.0) (1.14.1)
# Collecting scikit-learn<2,>=1.3.2 (from imbalanced-learn==0.13.0)
#   Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from imbalanced-learn==0.13.0) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from imbalanced-learn==0.13.0) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from imbalanced-learn==0.13.0) (3.5.0)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 11.5 MB/s eta 0:00:00 0:00:01
# Installing collected packages: scikit-learn, imbalanced-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
# Successfully installed imbalanced-learn-0.13.0 scikit-learn-1.6.1
# Collecting tensorflow==2.18.0
#   Downloading tensorflow-2.18.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (4.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (3.9.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (1.26.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorflow==2.18.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.18.0) (0.45.1)
# Requirement already satisfied: rich in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow==2.18.0) (13.9.4)
# Requirement already satisfied: namex in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow==2.18.0) (0.0.8)
# Requirement already satisfied: optree in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow==2.18.0) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow==2.18.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow==2.18.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow==2.18.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/silach53/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.18.0) (0.1.2)
# Downloading tensorflow-2.18.0-cp310-cp310-macosx_12_0_arm64.whl (239.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 MB 8.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: tensorflow
# Successfully installed tensorflow-2.18.0

# %%
# Импорт библиотек
import pandas as pd
import numpy as np
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.metrics import f1_score, classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns

# Преобразование целевой переменной
df['Attrition_Flag'] = df['Attrition_Flag'].map({'Attrited Customer': 1, 'Existing Customer': 0})

# Обработка категориальных признаков
df = pd.get_dummies(df, columns=['Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category'], 
                    drop_first=True)

# Удаление ID клиента
df.drop('CLIENTNUM', axis=1, inplace=True)

# Разделение на признаки и целевую переменную
X = df.drop('Attrition_Flag', axis=1)
y = df['Attrition_Flag']

# Балансировка классов с помощью SMOTE
smote = SMOTE(random_state=42)
X_balanced, y_balanced = smote.fit_resample(X, y)

# Разделение на тренировочную и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(
    X_balanced, y_balanced, test_size=0.2, random_state=42
)

# Создание и обучение моделей
models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'AdaBoost': AdaBoostClassifier(random_state=42),
    'SVM': SVC(random_state=42, probability=True)
}

results = {}
for name, model in models.items():
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('model', model)
    ])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    results[name] = {
        'f1': f1_score(y_test, y_pred),
        'report': classification_report(y_test, y_pred),
        'cm': confusion_matrix(y_test, y_pred)
    }

# Вывод результатов
for model_name, metrics in results.items():
    print(f'Model: {model_name}')
    print(f'F1 Score: {metrics["f1"]:.2f}')
    print('Classification Report:')
    print(metrics['report'])
    print('Confusion Matrix:')
    
    # Явное преобразование матрицы ошибок
    cm = np.array(metrics['cm'])
    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'{model_name} Confusion Matrix')
    plt.show()
    
    print('\n' + '='*50 + '\n')


# Оценка на исходных данных (без балансировки)
best_model = Pipeline([
    ('scaler', StandardScaler()),
    ('model', RandomForestClassifier(random_state=42))
])
best_model.fit(X_balanced, y_balanced)

y_pred_original = best_model.predict(X)
print('Evaluation on Original Data:')
print(classification_report(y, y_pred_original))
print('Confusion Matrix:')
print(confusion_matrix(y, y_pred_original))

# Анализ важности признаков
feature_importances = best_model.named_steps['model'].feature_importances_
features = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=features.head(10))
plt.title('Top 10 Important Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/silach53/ML_8_sem/Лабораторная 7/lab07.ipynb Cell 6 line 2
#      <a href='vscode-notebook-cell:/Users/silach53/ML_8_sem/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F%207/lab07.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a> df['Attrition_Flag'] = df['Attrition_Flag'].map({'Attrited Customer': 1, 'Existing Customer': 0})
#      <a href='vscode-notebook-cell:/Users/silach53/ML_8_sem/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F%207/lab07.ipynb#W4sZmlsZQ%3D%3D?line=18'>19</a> # Обработка категориальных признаков
# ---> <a href='vscode-notebook-cell:/Users/silach53/ML_8_sem/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F%207/lab07.ipynb#W4sZmlsZQ%3D%3D?line=19'>20</a> df = pd.get_dummies(df, columns=['Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category'],
#      <a href='vscode-notebook-cell:/Users/silach53/ML_8_sem/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F%207/lab07.ipynb#W4sZmlsZQ%3D%3D?line=20'>21</a>                     drop_first=True)
#      <a href='vscode-notebook-cell:/Users/silach53/ML_8_sem/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F%207/lab07.ipynb#W4sZmlsZQ%3D%3D?line=22'>23</a> # Удаление ID клиента
#      <a href='vscode-notebook-cell:/Users/silach53/ML_8_sem/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F%207/lab07.ipynb#W4sZmlsZQ%3D%3D?line=23'>24</a> df.drop('CLIENTNUM', axis=1, inplace=True)
#
# File ~/.pyenv/versions/3.10.5/lib/python3.10/site-packages/pandas/core/reshape/encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167     raise TypeError("Input must be a list-like for parameter `columns`")
#     168 else:
# --> 169     data_to_encode = data[columns]
#     171 # validate prefixes and separator to avoid silently dropping cols
#     172 def check_len(item, name: str):
#
# File ~/.pyenv/versions/3.10.5/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.10.5/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.10.5/lib/python3.10/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Gender', 'Education_Level', 'Marital_Status', 'Income_Category',\n       'Card_Category'],\n      dtype='object')] are in the [columns]"
